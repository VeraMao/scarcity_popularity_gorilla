# %% [markdown]
# # Data Analysis Self-Purchase Condition

# %%
import pandas as pd

# %%
q_df = pd.read_csv("data_exp_226982-vall_questionnaires.csv")

# %%
q_df.head()
# Out:
#   Event Index  UTC Timestamp     UTC Date and Time  Local Timestamp  \
# 0         NaN            NaN                   NaN              NaN
# 1          ﻿1   1.746994e+12  11/05/2025, 20:10:33     1.746976e+12
# 2          ﻿1   1.746996e+12  11/05/2025, 20:47:32     1.746978e+12
# 3          ﻿1   1.746997e+12  11/05/2025, 20:53:12     1.746979e+12
# 4          ﻿1   1.746997e+12  11/05/2025, 20:54:40     1.746979e+12
#
#    Local Timezone   Local Date and Time  Experiment ID  Experiment Version  \
# 0             NaN                   NaN            NaN                 NaN
# 1            -5.0  11/05/2025, 10:10:33       226982.0                 8.0
# 2            -5.0  11/05/2025, 10:47:32       226982.0                 9.0
# 3            -5.0  11/05/2025, 10:53:12       226982.0                10.0
# 4            -5.0  11/05/2025, 10:54:40       226982.0                10.0
#
#         Tree Node Key  Repeat Key  ...  \
# 0                 NaN         NaN  ...
# ...

# %%
t_df = pd.read_csv("data_exp_226982-vall_tasks.csv")

# %%
t_df.head()
# Out:
#   Event Index  UTC Timestamp     UTC Date and Time  Local Timestamp  \
# 0          ﻿1  1746994382204  11/05/2025, 20:13:02    1746976382204
# 1           2  1746994405096  11/05/2025, 20:13:25    1746976405096
# 2           3  1746994486632  11/05/2025, 20:14:46    1746976486632
# 3           4  1746994486635  11/05/2025, 20:14:46    1746976486635
# 4           5  1746994521307  11/05/2025, 20:15:21    1746976521307
#
#    Local Timezone   Local Date and Time  Experiment ID  Experiment Version  \
# 0              -5  11/05/2025, 10:13:02         226982                   8
# 1              -5  11/05/2025, 10:13:25         226982                   8
# 2              -5  11/05/2025, 10:14:46         226982                   8
# 3              -5  11/05/2025, 10:14:46         226982                   8
# 4              -5  11/05/2025, 10:15:21         226982                   8
#
#   Tree Node Key  Repeat Key  ...  Tag       Component Name  \
# ...

# %%
t_df.columns
# Out:
# Index(['Event Index', 'UTC Timestamp', 'UTC Date and Time', 'Local Timestamp',
#        'Local Timezone', 'Local Date and Time', 'Experiment ID',
#        'Experiment Version', 'Tree Node Key', 'Repeat Key', 'Schedule ID',
#        'Participant Private ID', 'Participant Starting Group',
#        'Participant Status', 'Participant Completion Code',
#        'Participant External Session ID', 'Participant Device Type',
#        'Participant Device', 'Participant OS', 'Participant Browser',
#        'Participant Monitor Size', 'Participant Viewport Size', 'Checkpoint',
#        'Task Name', 'Task Version', 'randomiser-7gnq', 'Current Spreadsheet',
#        'Trial Number', 'Display', 'Screen', 'Screen ID', 'Screen Counter',
#        'Response Type', 'Response', 'Onset Time', 'Clock Time',
#        'Reaction Time', 'Absolute Onset Time', 'Absolute Clock Time',
#        'Absolute Reaction Time', 'Correct', 'Response Duration', 'Proportion',
# ...

# %%
t_df = randomizer, email collection, task name, task version, consent form object
